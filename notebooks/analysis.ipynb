# %%
import pandas as pd
import json

file_path = '../data/btc_info.json'


with open(file_path) as f:
        data = json.load(f)

    # transformação do json em um dataframe
df = pd.json_normalize(data)
df.head()
# Out:
#        timestamp                                               data
# 0  1778632663832  [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC...
